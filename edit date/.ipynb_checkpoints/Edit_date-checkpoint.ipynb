# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv(r"C:\Users\mhmd\Downloads\Edit data\Orders.csv" , skiprows = 4)#هنا لو فيه اربع صفوف مش معانا هيسكيييب ومش هياخدهم
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        homs   hs01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      riyadh   rd01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      riyadh   rd03  24.7743
# 3           NaN        NaN                   NaN         NaN    NaN      NaN
# 4           4.0   1/1/2023  United Arab Emirates   abu dhabi   ad01  24.4539
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023                 Syria        homs   hs01  34.7326
# 20001   19998.0   1/9/2023                   USA   las vegas   lv01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023                   USA  washington   wh01  38.9072
#
# ...

# %%
df=pd.read_csv(r"C:\Users\mhmd\Downloads\Edit data\Orders.csv" , skiprows = 4)

df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        homs   hs01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      riyadh   rd01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      riyadh   rd03  24.7743
# 3           NaN        NaN                   NaN         NaN    NaN      NaN
# 4           4.0   1/1/2023  United Arab Emirates   abu dhabi   ad01  24.4539
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023                 Syria        homs   hs01  34.7326
# 20001   19998.0   1/9/2023                   USA   las vegas   lv01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023                   USA  washington   wh01  38.9072
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20004 entries, 0 to 20003
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order ID             20000 non-null  float64
#  1   Order Date           20000 non-null  object
#  2   Country              20000 non-null  object
#  3   City                 20000 non-null  object
#  4   Branch               20000 non-null  object
#  5   Lat                  20000 non-null  float64
#  6   Lng                  20000 non-null  float64
#  7   Customer First Name  20000 non-null  object
#  8   Customer Last Name   20000 non-null  object
#  9   Email                20000 non-null  object
#  10  Phone Number         20000 non-null  object
#  11  Category             20000 non-null  object
#  12  Sub Category         20000 non-null  object
#  13  Item                 20000 non-null  object
#  14  SalesPerson ID       20000 non-null  object
# ...

# %%
df.dropna()#شال كل ريكورد فارغ او فى قيمة واحدة من اي عمود فارغة
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        homs   hs01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      riyadh   rd01  24.7136
# 4           4.0   1/1/2023  United Arab Emirates   abu dhabi   ad01  24.4539
# 5           5.0   1/1/2023                   USA  washington   wh01  38.9072
# 6           6.0   1/1/2023                 Syria      aleppo   al01  36.2021
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023                 Syria        homs   hs01  34.7326
# 20001   19998.0   1/9/2023                   USA   las vegas   lv01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023                   USA  washington   wh01  38.9072
#
# ...

# %%
df.dropna(how="all" )#كدا لازم يكون الصف كلة فارغ مش قيمة واحدة
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        homs   hs01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      riyadh   rd01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      riyadh   rd03  24.7743
# 4           4.0   1/1/2023  United Arab Emirates   abu dhabi   ad01  24.4539
# 5           5.0   1/1/2023                   USA  washington   wh01  38.9072
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023                 Syria        homs   hs01  34.7326
# 20001   19998.0   1/9/2023                   USA   las vegas   lv01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023                   USA  washington   wh01  38.9072
#
# ...

# %%
df.dropna(how="all",inplace = True )

# %%
df[df['Status']==True]
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 1           2.0   1/1/2023          Saudi Arabia      riyadh   rd01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      riyadh   rd03  24.7743
# 4           4.0   1/1/2023  United Arab Emirates   abu dhabi   ad01  24.4539
# 5           5.0   1/1/2023                   USA  washington   wh01  38.9072
# 6           6.0   1/1/2023                 Syria      aleppo   al01  36.2021
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  casablanca   cs01  33.5731
# 20000   19997.0   1/9/2023                 Syria        homs   hs01  34.7326
# 20001   19998.0   1/9/2023                   USA   las vegas   lv01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      jeddah   jd03  21.4858
# 20003   20000.0   1/9/2023                   USA  washington   wh01  38.9072
#
# ...

# %%
df.query('Status==False')
# Out:
#        Order ID Order Date               Country       City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria       homs   hs01  34.7326
# 9           8.0   1/1/2023                 Egypt      cairo   cr02  30.0444
# 20         19.0   1/1/2023          Saudi Arabia     riyadh   rd01  24.7136
# 21         20.0   1/1/2023          Saudi Arabia     riyadh   rd02  24.7743
# 23         22.0   1/1/2023                   USA   new york   ny03  40.7498
# ...         ...        ...                   ...        ...    ...      ...
# 19990   19987.0   1/9/2023                 Egypt      asyut   at01  27.1809
# 19991   19988.0   1/9/2023          Saudi Arabia     riyadh   rd02  24.7743
# 19994   19991.0   1/9/2023          Saudi Arabia     jeddah   jd01  21.5433
# 19995   19992.0   1/9/2023                 Egypt      asyut   at01  27.1809
# 19996   19993.0   1/9/2023  United Arab Emirates  abu dhabi   ad01  24.4539
#
#            Lng Customer First Name Customer Last Name  \
# ...

# %%
df[df['Country']=='Saudi Arabia']
# Out:
#        Order ID Order Date       Country    City Branch      Lat      Lng  \
# 1           2.0   1/1/2023  Saudi Arabia  riyadh   rd01  24.7136  46.6753
# 2           3.0   1/1/2023  Saudi Arabia  riyadh   rd03  24.7743  46.7386
# 7           7.0   1/1/2023  Saudi Arabia  riyadh   rd01  24.7136  46.6753
# 10          9.0   1/1/2023  Saudi Arabia   aseer   as01  18.2311  42.5004
# 19         18.0   1/1/2023  Saudi Arabia  jeddah   jd01  21.5433  39.1728
# ...         ...        ...           ...     ...    ...      ...      ...
# 19989   19986.0   1/9/2023  Saudi Arabia   aseer   as01  18.2311  42.5004
# 19991   19988.0   1/9/2023  Saudi Arabia  riyadh   rd02  24.7743  46.7386
# 19993   19990.0   1/9/2023  Saudi Arabia  jeddah   jd01  21.5433  39.1728
# 19994   19991.0   1/9/2023  Saudi Arabia  jeddah   jd01  21.5433  39.1728
# 20002   19999.0   1/9/2023  Saudi Arabia  jeddah   jd03  21.4858  39.1925
#
#       Customer First Name Customer Last Name                     Email  \
# ...

# %%
df[(df['Country']=='Saudi Arabia') & (df['Quantity']>10)]
# Out:
#        Order ID Order Date       Country    City Branch      Lat      Lng  \
# 83         80.0   1/1/2023  Saudi Arabia  jeddah   jd03  21.4858  39.1925
# 343       340.0   5/1/2023  Saudi Arabia  jeddah   jd02  21.4858  39.1925
# 429       426.0   6/1/2023  Saudi Arabia   aseer   as01  18.2311  42.5004
# 464       461.0   6/1/2023  Saudi Arabia  riyadh   rd03  24.7743  46.7386
# 497       494.0   7/1/2023  Saudi Arabia  jeddah   jd02  21.4858  39.1925
# ...         ...        ...           ...     ...    ...      ...      ...
# 19618   19615.0  28/8/2023  Saudi Arabia  jeddah   jd02  21.4858  39.1925
# 19653   19650.0  28/8/2023  Saudi Arabia  riyadh   rd01  24.7136  46.6753
# 19710   19707.0  29/8/2023  Saudi Arabia  jeddah   jd03  21.4858  39.1925
# 19753   19750.0  29/8/2023  Saudi Arabia  dammam   dm01  26.3927  49.9777
# 19987   19984.0   1/9/2023  Saudi Arabia  jeddah   jd02  21.4858  39.1925
#
#       Customer First Name Customer Last Name                          Email  \
# ...

# %%
df[(df['Category']=='Laptop') | (df['Category']=='Smartphone')]
# Out:
#        Order ID Order Date               Country       City Branch      Lat  \
# 1           2.0   1/1/2023          Saudi Arabia     riyadh   rd01  24.7136
# 10          9.0   1/1/2023          Saudi Arabia      aseer   as01  18.2311
# 12         11.0   1/1/2023                 Egypt      cairo   cr03  30.0444
# 26         25.0   1/1/2023  United Arab Emirates  abu dhabi   ad01  24.4539
# 27         26.0   1/1/2023                 Syria   damascus   ds02  33.5146
# ...         ...        ...                   ...        ...    ...      ...
# 19973   19970.0   1/9/2023                   USA   new york   ny03  40.7498
# 19977   19974.0   1/9/2023                   USA   new york   ny01  40.7128
# 19983   19980.0   1/9/2023  United Arab Emirates  abu dhabi   ad01  24.4539
# 19990   19987.0   1/9/2023                 Egypt      asyut   at01  27.1809
# 19992   19989.0   1/9/2023                 Syria   damascus   ds02  33.5146
#
#            Lng Customer First Name Customer Last Name  \
# ...

# %%
df[df['Category'].isin(['Laptop', 'Smartphone'])]
# Out:
#        Order ID Order Date               Country       City Branch      Lat  \
# 1           2.0   1/1/2023          Saudi Arabia     riyadh   rd01  24.7136
# 10          9.0   1/1/2023          Saudi Arabia      aseer   as01  18.2311
# 12         11.0   1/1/2023                 Egypt      cairo   cr03  30.0444
# 26         25.0   1/1/2023  United Arab Emirates  abu dhabi   ad01  24.4539
# 27         26.0   1/1/2023                 Syria   damascus   ds02  33.5146
# ...         ...        ...                   ...        ...    ...      ...
# 19973   19970.0   1/9/2023                   USA   new york   ny03  40.7498
# 19977   19974.0   1/9/2023                   USA   new york   ny01  40.7128
# 19983   19980.0   1/9/2023  United Arab Emirates  abu dhabi   ad01  24.4539
# 19990   19987.0   1/9/2023                 Egypt      asyut   at01  27.1809
# 19992   19989.0   1/9/2023                 Syria   damascus   ds02  33.5146
#
#            Lng Customer First Name Customer Last Name  \
# ...

# %%
df[df['Item'].str.contains('S21 ')]#يحتوى جواه على هذه الكلمة
# Out:
#        Order ID Order Date               Country       City Branch      Lat  \
# 1           2.0   1/1/2023          Saudi Arabia     riyadh   rd01  24.7136
# 33         31.0   1/1/2023                   USA   new york   ny01  40.7128
# 78         75.0   1/1/2023  United Arab Emirates      dubai   db02  25.2048
# 480       477.0   6/1/2023                France      paris   ps02  48.8566
# 509       506.0   7/1/2023  United Arab Emirates      dubai   db01  25.2048
# ...         ...        ...                   ...        ...    ...      ...
# 18306   18303.0  11/8/2023          Saudi Arabia     jeddah   jd01  21.5433
# 18358   18355.0  12/8/2023  United Arab Emirates  abu dhabi   ad01  24.4539
# 18781   18778.0  17/8/2023                 Syria       homs   hs01  34.7326
# 18830   18827.0  18/8/2023          Saudi Arabia     jeddah   jd01  21.5433
# 19227   19224.0  23/8/2023          Saudi Arabia     riyadh   rd01  24.7136
#
#            Lng Customer First Name Customer Last Name  \
# ...

# %%
df[df['Sub Category'].str.startswith('Apple')]#startswith , endswith
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        homs   hs01  34.7326
# 11         10.0   1/1/2023                   USA  washington   wh01  38.9072
# 27         26.0   1/1/2023                 Syria    damascus   ds02  33.5146
# 43         41.0   1/1/2023                   USA    new york   ny01  40.7128
# 82         79.0   1/1/2023          Saudi Arabia      jeddah   jd02  21.4858
# ...         ...        ...                   ...         ...    ...      ...
# 19893   19890.0  31/8/2023                   USA    new york   ny03  40.7498
# 19911   19908.0  31/8/2023                 Egypt       cairo   cr02  30.0444
# 19923   19920.0  31/8/2023                 Syria      aleppo   al01  36.2021
# 19964   19961.0   1/9/2023          Saudi Arabia      riyadh   rd01  24.7136
# 19983   19980.0   1/9/2023  United Arab Emirates   abu dhabi   ad01  24.4539
#
# ...

# %%
df[(df['Branch'].str.contains('hs')) & (df['Category'].str.startswith('Smart'))]
# Out:
#        Order ID Order Date Country  City Branch      Lat      Lng  \
# 159       156.0   2/1/2023   Syria  homs   hs01  34.7326  36.7136
# 209       206.0   3/1/2023   Syria  homs   hs01  34.7326  36.7136
# 355       352.0   5/1/2023   Syria  homs   hs01  34.7326  36.7136
# 356       353.0   5/1/2023   Syria  homs   hs01  34.7326  36.7136
# 612       609.0   8/1/2023   Syria  homs   hs01  34.7326  36.7136
# ...         ...        ...     ...   ...    ...      ...      ...
# 19545   19542.0  27/8/2023   Syria  homs   hs01  34.7326  36.7136
# 19742   19739.0  29/8/2023   Syria  homs   hs01  34.7326  36.7136
# 19803   19800.0  30/8/2023   Syria  homs   hs01  34.7326  36.7136
# 19886   19883.0  31/8/2023   Syria  homs   hs01  34.7326  36.7136
# 20000   19997.0   1/9/2023   Syria  homs   hs01  34.7326  36.7136
#
#       Customer First Name Customer Last Name                       Email  \
# 159                dijwar              watar       dijwar.watar@mail.com
# ...

# %%
df[(df['Country'] ==('Syria')) & (df['Category'].str.startswith('Smart'))]
# Out:
#        Order ID Order Date Country      City Branch      Lat      Lng  \
# 6           6.0   1/1/2023   Syria    Aleppo   AL01  36.2021  37.1343
# 52         50.0   1/1/2023   Syria  Damascus   DS02  33.5146  36.3084
# 69         66.0   1/1/2023   Syria    Aleppo   AL01  36.2021  37.1343
# 85         82.0   1/1/2023   Syria    Aleppo   AL01  36.2021  37.1343
# 136       133.0   2/1/2023   Syria  Damascus   DS02  33.5146  36.3084
# ...         ...        ...     ...       ...    ...      ...      ...
# 19839   19836.0  30/8/2023   Syria  Damascus   DS02  33.5146  36.3084
# 19875   19872.0  31/8/2023   Syria  Damascus   DS02  33.5146  36.3084
# 19886   19883.0  31/8/2023   Syria      Homs   HS01  34.7326  36.7136
# 19923   19920.0  31/8/2023   Syria    Aleppo   AL01  36.2021  37.1343
# 20000   19997.0   1/9/2023   Syria      Homs   HS01  34.7326  36.7136
#
#       Customer First Name Customer Last Name                    Email  \
# ...

# %%
df['City'].str.title()
# Out:
# 0              Homs
# 1            Riyadh
# 2            Riyadh
# 4         Abu Dhabi
# 5        Washington
#             ...
# 19999    Casablanca
# 20000          Homs
# 20001     Las Vegas
# 20002        Jeddah
# 20003    Washington
# Name: City, Length: 20000, dtype: object

# %%
df['City'].str.capitalize()
# Out:
# 0              Homs
# 1            Riyadh
# 2            Riyadh
# 4         Abu dhabi
# 5        Washington
#             ...
# 19999    Casablanca
# 20000          Homs
# 20001     Las vegas
# 20002        Jeddah
# 20003    Washington
# Name: City, Length: 20000, dtype: object

# %%
df['City'] = df['City'].str.capitalize()

# %%
df['Branch'] = df['Branch'].str.upper()
df['Email'] = df['Email'].str.lower()

# %%
df
# Out:
#        Order ID Order Date               Country        City Branch      Lat  \
# 0           1.0   1/1/2023                 Syria        Homs   HS01  34.7326
# 1           2.0   1/1/2023          Saudi Arabia      Riyadh   RD01  24.7136
# 2           3.0   1/1/2023          Saudi Arabia      Riyadh   RD03  24.7743
# 4           4.0   1/1/2023  United Arab Emirates   Abu dhabi   AD01  24.4539
# 5           5.0   1/1/2023                   USA  Washington   WH01  38.9072
# ...         ...        ...                   ...         ...    ...      ...
# 19999   19996.0   1/9/2023               Morocco  Casablanca   CS01  33.5731
# 20000   19997.0   1/9/2023                 Syria        Homs   HS01  34.7326
# 20001   19998.0   1/9/2023                   USA   Las vegas   LV01  36.1699
# 20002   19999.0   1/9/2023          Saudi Arabia      Jeddah   JD03  21.4858
# 20003   20000.0   1/9/2023                   USA  Washington   WH01  38.9072
#
# ...
