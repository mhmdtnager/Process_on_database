# %%
import pandas as pd 
import numpy as np
import csv

pd.read_csv(r'C:/Users/mhmd/Downloads/import data/houses.csv')
# Out:
#                Timestamp       House
# 0    10/13/2021 14:32:13  Gryffindor
# 1    10/13/2021 16:00:07   Ravenclaw
# 2    10/13/2021 16:00:07  Gryffindor
# 3    10/13/2021 16:00:09   Ravenclaw
# 4    10/13/2021 16:00:10  Gryffindor
# ..                   ...         ...
# 581   10/21/2021 5:23:35   Ravenclaw
# 582  10/22/2021 10:58:15  Hufflepuff
# 583  10/23/2021 15:45:07   Slytherin
# 584  10/23/2021 23:48:03  Hufflepuff
# 585    6/4/2022 15:50:48   Ravenclaw
#
# [586 rows x 2 columns]

# %%
import pandas as pd 
import numpy as np
import csv

pd.read_csv(r'C:/Users/mhmd/Downloads/import data/orders/part-00000')
# Out:
#            1  2013-07-25 00:00:00.0  11599           CLOSED
# 0          2  2013-07-25 00:00:00.0    256  PENDING_PAYMENT
# 1          3  2013-07-25 00:00:00.0  12111         COMPLETE
# 2          4  2013-07-25 00:00:00.0   8827           CLOSED
# 3          5  2013-07-25 00:00:00.0  11318         COMPLETE
# 4          6  2013-07-25 00:00:00.0   7130         COMPLETE
# ...      ...                    ...    ...              ...
# 68877  68879  2014-07-09 00:00:00.0    778         COMPLETE
# 68878  68880  2014-07-13 00:00:00.0   1117         COMPLETE
# 68879  68881  2014-07-19 00:00:00.0   2518  PENDING_PAYMENT
# 68880  68882  2014-07-22 00:00:00.0  10000          ON_HOLD
# 68881  68883  2014-07-23 00:00:00.0   5533         COMPLETE
#
# [68882 rows x 4 columns]

# %%
header_column = ['order_id','order_date','order_customer_id','order_status']

# %%
import pandas as pd 
import numpy as np
import csv

pd.read_csv(r'C:/Users/mhmd/Downloads/import data/orders/part-00000',
           names = header_column)
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
pd.read_html #لو عايز استورد موقع من على النت فى جدول مثلا
# Out:
# <function pandas.io.html.read_html(io: 'FilePath | ReadBuffer[str]', *, match: 'str | Pattern' = '.+', flavor: 'str | None' = None, header: 'int | Sequence[int] | None' = None, index_col: 'int | Sequence[int] | None' = None, skiprows: 'int | Sequence[int] | slice | None' = None, attrs: 'dict[str, str] | None' = None, parse_dates: 'bool' = False, thousands: 'str | None' = ',', encoding: 'str | None' = None, decimal: 'str' = '.', converters: 'dict | None' = None, na_values: 'Iterable[object] | None' = None, keep_default_na: 'bool' = True, displayed_only: 'bool' = True, extract_links: "Literal[None, 'header', 'footer', 'body', 'all']" = None, dtype_backend: 'DtypeBackend | lib.NoDefault' = <no_default>, storage_options: 'StorageOptions' = None) -> 'list[DataFrame]'>

# %%
df = pd.read_csv(r'C:/Users/mhmd/Downloads/import data/orders/part-00000',
                     names = header_column)

# %%
df
# Out:
#        order_id             order_date  order_customer_id     order_status
# 0             1  2013-07-25 00:00:00.0              11599           CLOSED
# 1             2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3             4  2013-07-25 00:00:00.0               8827           CLOSED
# 4             5  2013-07-25 00:00:00.0              11318         COMPLETE
# ...         ...                    ...                ...              ...
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE
#
# [68883 rows x 4 columns]

# %%
df.head(10)#اول عشر ريكورد
# Out:
#    order_id             order_date  order_customer_id     order_status
# 0         1  2013-07-25 00:00:00.0              11599           CLOSED
# 1         2  2013-07-25 00:00:00.0                256  PENDING_PAYMENT
# 2         3  2013-07-25 00:00:00.0              12111         COMPLETE
# 3         4  2013-07-25 00:00:00.0               8827           CLOSED
# 4         5  2013-07-25 00:00:00.0              11318         COMPLETE
# 5         6  2013-07-25 00:00:00.0               7130         COMPLETE
# 6         7  2013-07-25 00:00:00.0               4530         COMPLETE
# 7         8  2013-07-25 00:00:00.0               2911       PROCESSING
# 8         9  2013-07-25 00:00:00.0               5657  PENDING_PAYMENT
# 9        10  2013-07-25 00:00:00.0               5648  PENDING_PAYMENT

# %%
df.tail(8)#اخر تمانية ريكورد
# Out:
#        order_id             order_date  order_customer_id     order_status
# 68875     68876  2014-07-06 00:00:00.0               4124         COMPLETE
# 68876     68877  2014-07-07 00:00:00.0               9692          ON_HOLD
# 68877     68878  2014-07-08 00:00:00.0               6753         COMPLETE
# 68878     68879  2014-07-09 00:00:00.0                778         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0               1117         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0               2518  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0              10000          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0               5533         COMPLETE

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(df['order_status'])
# Out:
# pandas.core.series.Series

# %%
df2=df[['order_id','order_date','order_status']]
df2
# Out:
#        order_id             order_date     order_status
# 0             1  2013-07-25 00:00:00.0           CLOSED
# 1             2  2013-07-25 00:00:00.0  PENDING_PAYMENT
# 2             3  2013-07-25 00:00:00.0         COMPLETE
# 3             4  2013-07-25 00:00:00.0           CLOSED
# 4             5  2013-07-25 00:00:00.0         COMPLETE
# ...         ...                    ...              ...
# 68878     68879  2014-07-09 00:00:00.0         COMPLETE
# 68879     68880  2014-07-13 00:00:00.0         COMPLETE
# 68880     68881  2014-07-19 00:00:00.0  PENDING_PAYMENT
# 68881     68882  2014-07-22 00:00:00.0          ON_HOLD
# 68882     68883  2014-07-23 00:00:00.0         COMPLETE
#
# [68883 rows x 3 columns]

# %%
df.describe()
# Out:
#            order_id  order_customer_id
# count  68883.000000       68883.000000
# mean   34442.000000        6216.571099
# std    19884.953633        3586.205241
# min        1.000000           1.000000
# 25%    17221.500000        3122.000000
# 50%    34442.000000        6199.000000
# 75%    51662.500000        9326.000000
# max    68883.000000       12435.000000

# %%
df['order_customer_id'].describe()
# Out:
# count    68883.000000
# mean      6216.571099
# std       3586.205241
# min          1.000000
# 25%       3122.000000
# 50%       6199.000000
# 75%       9326.000000
# max      12435.000000
# Name: order_customer_id, dtype: float64

# %%
df.sum()
# Out:
# order_id                                                    2372468286
# order_date           2013-07-25 00:00:00.02013-07-25 00:00:00.02013...
# order_customer_id                                            428216067
# order_status         CLOSEDPENDING_PAYMENTCOMPLETECLOSEDCOMPLETECOM...
# dtype: object

# %%
df.agg(['sum','count'])
# Out:
#          order_id                                         order_date  \
# sum    2372468286  2013-07-25 00:00:00.02013-07-25 00:00:00.02013...
# count       68883                                              68883
#
#        order_customer_id                                       order_status
# sum            428216067  CLOSEDPENDING_PAYMENTCOMPLETECLOSEDCOMPLETECOM...
# count              68883                                              68883

# %%
df_group = df.groupby('order_status').agg(['sum','count'])#.sum()لو عملية واحدة
# Out:
#          order_id                                         order_date  \
# sum    2372468286  2013-07-25 00:00:00.02013-07-26 00:00:00.02013...
# count           9                                                  9
#
#        order_customer_id
# sum            428216067
# count                  9

# %%
df_group = df.groupby('order_status').agg(['sum','count'])
df_group
# Out:
#                   order_id         \
#                        sum  count
# order_status
# CANCELED          49540191   1428
# CLOSED           256816207   7556
# COMPLETE         789600262  22899
# ON_HOLD          130845249   3798
# PAYMENT_REVIEW    25126996    729
# PENDING          264303939   7610
# PENDING_PAYMENT  516200083  15030
# PROCESSING       286158867   8275
# SUSPECTED_FRAUD   53876492   1558
#
#                                                         order_date         \
#                                                                sum  count
# order_status
# CANCELED         2013-07-25 00:00:00.02013-07-26 00:00:00.02013...   1428
# CLOSED           2013-07-25 00:00:00.02013-07-25 00:00:00.02013...   7556
# COMPLETE         2013-07-25 00:00:00.02013-07-25 00:00:00.02013...  22899
# ON_HOLD          2013-07-25 00:00:00.02013-07-25 00:00:00.02013...   3798
# PAYMENT_REVIEW   2013-07-25 00:00:00.02013-07-25 00:00:00.02013...    729
# ...

# %%
df_group.plot()
# Out:
# <Axes: xlabel='order_status'>

# %%
df_group.plot(kind="bar")
# Out:
# <Axes: xlabel='order_status'>

# %%
df_group.plot(kind='box')
# Out:
# <Axes: >
